# %% [markdown]
# <a href="https://colab.research.google.com/github/DoniyorbekErkinov/Games/blob/main/first_nt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Salom Doniyor')
# Out:
# Salom Doniyor

# %%
x = 4
y = 8
print(x * y - 8 * 2/8)
# Out:
# 30.0

# %% [markdown]
# Salom Doniyor

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import pandas as pd

files = pd.read_excel('./Data/random_data.xlsx')

files.head()
# Out:
#     Column1   Column2   Column3   Column4   Column5   Column6   Column7  \
# 0  0.249605  0.775334  0.902326  0.366297  0.855530  0.781349  0.616726
# 1  0.304823  0.551701  0.484773  0.285871  0.289872  0.575827  0.209332
# 2  0.204247  0.456289  0.511956  0.207248  0.939416  0.673768  0.256547
# 3  0.740850  0.962038  0.492012  0.482370  0.597103  0.377750  0.838173
# 4  0.650473  0.443633  0.928299  0.201356  0.252443  0.924399  0.006285
#
#     Column8   Column9  Column10  ...  Column16  Column17  Column18  Column19  \
# 0  0.493525  0.959200  0.375317  ...  0.444311  0.428157  0.619638  0.368971
# 1  0.803750  0.593696  0.716294  ...  0.426497  0.443839  0.749751  0.325818
# 2  0.038674  0.858550  0.357733  ...  0.687652  0.163544  0.520723  0.466861
# 3  0.048198  0.448187  0.123861  ...  0.821007  0.673999  0.221313  0.881068
# 4  0.386465  0.366141  0.060793  ...  0.136638  0.720499  0.477120  0.084557
#
#    Column20  Column21  Column22  Column23  Column24  Column25
# ...
